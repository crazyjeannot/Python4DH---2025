# %% [markdown]
# # Analyse de Données structurées
#
#
# On a déjà vu comment analyser certains type de données, comme le plein texte ou les CSV/TSV.
#
# Il existe de nombreux autres structures de données, comme le XML, le JSON ou le PDF, que nous allons voir maintenant !
#
# ### XML
#
# [librairie lxml](https://lxml.de/)

# %%
import lxml

# %% [markdown]
# ### Introduction
# La bibliothèque lxml en Python pour analyser et extraire des informations à partir d'un fichier XML. Plus précisément, nous travaillerons avec un fichier XML TEI (Text Encoding Initiative) contenant des informations sur un roman et son auteur.
#
# ### Installation de la bibliothèque lxml
# Avant de commencer, assurez-vous d'avoir la bibliothèque lxml installée. Vous pouvez l'installer avec la commande suivante :

# %%
# !pip install lxml

# %% [markdown]
# ### Importation de `etree` de lxml.

# %%
from lxml import etree

# %% [markdown]
# Le module `etree` offre une interface pratique et flexible pour travailler avec XML. Les concepts clés comprennent :
# - `etree.parse` : Charge un fichier XML dans un ElementTree.
# - `element.xpath` : Effectue des requêtes XPath sur un élément.
# - `element.text` : Récupère le contenu textuel d'un élément.

# %%
chemin_fichier_xml = '/Users/rolly/Documents/10-19_Université_et_scolarité/Python4DH---2024/seance_06/to_send/data/1843_Balzac-Honore-de_Le-Pere-Goriot.xml'
arbre = etree.parse(chemin_fichier_xml)

# %%
arbre

# %%
arbre.find(".//profileDesc")
# Out:
# <Element profileDesc at 0x11550ab40>

# %%
arbre.find(".//profileDesc").text
# Out:
# '\n          '

# %%
arbre.find(".//profileDesc").get("tag")
# Out:
# 'canon'

# %%
arbre.find(".//term").text
# Out:
# 'cycles et séries'

# %% [markdown]
# ### Exercices !
#
# 1/ Écrire une fonction qui lit tous les fichiers XML, créé et sauvegarde un dataframe avec 8 colonnes : titre, auteur, gender, genre, canon, date, date_naissance, date_mort
#
# 2/ Écrire une fonction qui convertie les xml en fichiers txt.

# %%
arbre.find(".//title").text
# Out:
# 'Le Père Goriot'

# %%
<author from="1799" key="" name="Balzac, Honoré de" sex="male" to="1850"/>

# %%
arbre.find(".//author").get("sex")
# Out:
# 'male'

# %% [markdown]
# ### JSON
#
# [json librairie](https://docs.python.org/3/library/json.html)

# %%
import json

# %%
path = '/Users/rolly/Documents/10-19_Université_et_scolarité/Python4DH---2024/data/booknlp_output_book/1830_Stendhal_Le-Rouge-et-le-noir.book'

# %%
with open(path_book, "r") as booknlp_book:
    book_data = json.load(booknlp_book)

# %%
type(book_data)
# Out:
# dict

# %%
book_data['characters'][0].keys()
# Out:
# dict_keys(['agent', 'patient', 'mod', 'poss', 'id', 'g', 'count', 'mentions'])

# %%
book_data['characters'][0]['g']
# Out:
# {'inference': {'il/le': 0.156, 'elle/la': 0.844},
#  'argmax': 'elle/la',
#  'max': 0.844,
#  'total': 40.058}

# %%
def get_characterization(booknlp_data, N):
    list_verb_suj, list_verb_obj, list_adj = [], [], []
    for i in range(N):
        list_verb_suj.extend([item['w'] for item in booknlp_data["characters"][i]['agent']])
        list_verb_obj.extend([item['w'] for item in booknlp_data["characters"][i]['patient']])
        list_adj.extend([item['w'] for item in booknlp_data["characters"][i]['mod']])
    return list_verb_suj, list_verb_obj, list_adj

# %%
list_verb_suj, list_verb_obj, list_adj = get_characterization(book_data, 10)

# %%
list_verb_suj
# Out:
# ['voulait',
#  'vingt-trois',
#  'failli',
#  'retenue',
#  'venez',
#  'jouissez',
#  'dit',
#  'eut',
#  'tourna',
#  'dit',
#  'gagnait',
#  'remercie',
#  'n’',
#  'respirait',
#  'voulu',
#  'enviait',
#  'allait',
#  'mue',
#  'songeait',
#  'travaillée',
#  'travaillée',
#  'croyait',
#  'arriva',
#  'donna',
#  'couvrit',
#  'recommanda',
#  'convainquit',
#  'courut',
#  'n’',
#  'alla',
#  'reçu',
#  'remarquer',
#  'm’',
#  'entendait',
#  'étudié',
#  'servait',
#  'faisait',
#  'leva',
#  'regarda',
#  'demanda',
#  'mit',
#  'laça',
#  'connut',
#  'entendit',
#  'étonna',
#  'trouva',
#  'eut',
#  'plut',
#  'appartenait',
#  'ressemblait',
#  'avait',
#  'avait',
#  'belle',
#  'ouvrit',
#  'tendit',
#  'vu',
#  'sauva',
#  'éprouvait',
#  'prit',
#  'répondit',
#  'pèse',
#  'ferai',
#  'pensais',
#  'n’',
#  'm’',
#  'passerez',
#  'cuiras',
#  'connais',
#  'apportera',
#  'laisseront',
#  'alla',
#  'écoutait',
#  'touchait',
#  'allait',
#  'arrivé',
#  'dit',
#  'trouvé',
#  'dit',
#  'achetés',
#  'regardait',
#  'dirai',
#  '…',
#  'commençaient',
#  'vit',
#  'attachait',
#  'revint',
#  'arrivant',
#  'respira',
#  'dit',
#  'aime',
#  'apprit',
#  'répondit',
#  'n’',
#  'dit',
#  'dit',
#  'dit',
#  'jeta',
#  'plut',
#  'donna',
#  'alla',
#  'prit',
#  'fit',
#  'allait',
#  'venait',
#  'trottait',
#  'sautait',
#  'voulu',
#  'réussit',
#  'dérogeait',
#  'réussit',
#  'dérogeait',
#  'lancerait',
#  'vient',
#  'prendrai',
#  't’',
#  'dit',
#  'déjeune',
#  'lève',
#  'laisserai',
#  'voulais',
#  'mangerais',
#  'voulu',
#  'n’',
#  'dit',
#  'allait',
#  'dit',
#  'ôta',
#  'reprit',
#  'offrit',
#  'dit',
#  'vois',
#  'veux',
#  'comprends',
#  'frissonna',
#  'commença',
#  'donne',
#  'veux',
#  'payerai',
#  'embrassait',
#  'dit',
#  'laisse',
#  'vais',
#  'tiré',
#  'respirèrent',
#  'comprenant',
#  'comptais',
#  'crois',
#  'embrassé',
#  'dit',
#  'descendirent',
#  'dire',
#  'dit',
#  'porterons',
#  'tirait',
#  'tournant',
#  'envoie',
#  'répondit',
#  'regarda',
#  'toucherai',
#  'ferai',
#  'retirerai',
#  'dit',
#  'savez',
#  'donnerez',
#  'coula',
#  'voyait',
#  'rêvait',
#  'rêvait',
#  'entendit',
#  'vêtit',
#  'put',
#  'raisonna',
#  'désirait',
#  'entra',
#  'dit',
#  'regarda',
#  'employait',
#  'assuraient',
#  'alla',
#  'vint',
#  'trouvez',
#  'descendit',
#  'voyait',
#  'mit',
#  'tenait',
#  'prit',
#  'tourna',
#  'regarda',
#  'trouva',
#  'pût',
#  'possédait',
#  'resta',
#  'savais',
#  'passa',
#  'donna',
#  'connaissait',
#  'commençait',
#  'pouvait',
#  'plongeait',
#  'retirait',
#  'croyant',
#  'prenait',
#  'finit',
#  'mettait',
#  'habitua',
#  'occupait',
#  'occupait',
#  'venait',
#  'décacheta',
#  'croisa',
#  'vinrent',
#  'devenu',
#  'pense',
#  'songeais',
#  'n’',
#  'souvenu',
#  'dit',
#  'pensais',
#  'dois',
#  'formées',
#  'parlerai',
#  'crois',
#  'possède',
#  'avouerai',
#  'aime',
#  'expose',
#  'n’',
#  'souviens',
#  'pense',
#  'souviens',
#  'souviens',
#  'contenterai',
#  'pur',
#  'dit',
#  'jeta',
#  'souvenant',
#  'dit',
#  'vint',
#  'passa',
#  'retrouva',
#  'servait',
#  'donnait',
#  'n’',
#  'voulais',
#  'dit',
#  'revenez',
#  'prit',
#  'reprit',
#  'fallu',
#  'acheva',
#  'écria',
#  'exprimé',
#  'venu',
#  'donnés',
#  'dévoué',
#  'vais',
#  'embarqué',
#  'fait',
#  'fait',
#  'rendit',
#  'remercie',
#  'avez',
#  'donna',
#  'allait',
#  'voulez',
#  'parut',
#  'satisfaite',
#  'sut',
#  'sut',
#  'dit',
#  'dit',
#  'sais',
#  'n’',
#  'répondit',
#  'n’',
#  'prié',
#  'aimait',
#  'quitté',
#  'rassura',
#  'enlèverait',
#  'entendu',
#  'entendit',
#  'venait',
#  'dit',
#  'dormait',
#  'entra',
#  'lisait',
#  'lirai',
#  'dois',
#  'regarda',
#  'prit',
#  'laissa',
#  'releva',
#  'baisa',
#  'baisa',
#  'sais',
#  'lirai',
#  'fais',
#  'lirai',
#  'orphelin',
#  'dois',
#  'puis',
#  'dois',
#  'viens',
#  'veux',
#  'n’',
#  'saurais',
#  'dit',
#  'fit',
#  'eut',
#  'reprit',
#  'sais',
#  'saurais',
#  'dois',
#  'dois',
#  't’',
#  'paraît',
#  'dit',
#  'justifiait',
#  'résonnaient',
#  'caressaient',
#  'caressaient',
#  'aimait',
#  'pleurait',
#  'empêché',
#  'ajournés',
#  '-',
#  'sais',
#  'eu',
#  'laissa',
#  'jura',
#  'jeta',
#  'commença',
#  'prêtait',
#  'choisissait',
#  'ouvrit',
#  'voyait',
#  'prit',
#  'rouge',
#  'pesa',
#  'plut',
#  'sépara',
#  'pensait',
#  'songeait',
#  'parvint',
#  'possédait',
#  'mit',
#  'remit',
#  'montra',
#  'réveilla',
#  'montée',
#  'dit',
#  'ignorais',
#  'plia',
#  'n’',
#  'sache',
#  'passerai',
#  'n’',
#  'pensais',
#  'convulsivement',
#  'veux',
#  'devrais',
#  'périssais',
#  'dédommagerait',
#  'puis',
#  'n’',
#  'taisait',
#  'venait',
#  'jeta',
#  'ressemblez',
#  'dit',
#  'fatigué',
#  'dégagea',
#  'sais',
#  'dit',
#  'retira',
#  'dirent',
#  'dit',
#  'aviez',
#  'contemplait',
#  'demandés',
#  'répondit',
#  'dit',
#  'dit',
#  'conserverait',
#  'compterai',
#  'remercie',
#  'te',
#  'n’',
#  'assirent',
#  'conduit',
#  'dois',
#  'puis',
#  'périr',
#  'sauva',
#  'retira',
#  'ouvrit',
#  'allait',
#  'trouva',
#  'prit',
#  'résista',
#  'reçut',
#  'donna',
#  'reprit',
#  'mit',
#  'annoncé',
#  'voulait',
#  'pleurait',
#  'élançait',
#  'mit',
#  'n’',
#  'sortira',
#  'donna',
#  'voudrais',
#  'dit',
#  'vit',
#  'initiait',
#  'devait',
#  'voulut',
#  'pouvait',
#  'ressemblait',
#  'conçu',
#  'alla',
#  'fait',
#  'fait',
#  'prit',
#  'cloua',
#  'restait',
#  'pensait',
#  'dissimulait',
#  'causait',
#  'eu',
#  'pensais',
#  'répondit',
#  'altérée',
#  'repens',
#  'n’',
#  'n’',
#  'te',
#  'vais',
#  'te',
#  'te',
#  'te',
#  'te',
#  'leva',
#  'retourna',
#  'n’',
#  'tombait',
#  'tarda',
#  'crois',
#  'aime',
#  'respecte',
#  'ferai',
#  'dit',
#  'fait',
#  'pouvez',
#  'donné',
#  'puis',
#  'fit',
#  'aviez',
#  'réitéra',
#  'saurai',
#  'sais',
#  'donné',
#  'placé',
#  'avez',
#  'restait',
#  'bougera',
#  'sourcillera',
#  'êtes',
#  'devez',
#  'ordonnent',
#  'baissa',
#  'veux',
#  'demeurerez',
#  'permette',
#  'leva',
#  'donné',
#  'jetés',
#  'pu',
#  'doré',
#  'vaut',
#  'eu',
#  'dit',
#  'demanderai',
#  'répondit',
#  'répondit',
#  'fait',
#  'point',
#  'allait',
#  'adressait',
#  'répondait',
#  'venait',
#  'apportait',
#  'souffrez',
#  'peignait',
#  'regardait',
#  'asseyait',
#  'mettait',
#  'succède',
#  'cria',
#  'apporté',
#  'donné',
#  'te',
#  'tremblait',
#  'éclatante',
#  'aime',
#  'épousera',
#  'veut',
#  'gardera',
#  'éteignit',
#  'allait',
#  'regrettait',
#  'tremblait',
#  'trouva',
#  'née',
#  'souffert',
#  'pourrais',
#  'crois',
#  'fasse',
#  'fasse',
#  'comprends',
#  'dois',
#  'aime',
#  'accomplissait',
#  'tint',
#  'étendait',
#  'demeurait',
#  'baignât',
#  'arrivé',
#  'devint',
#  'conduisait',
#  'pensait',
#  'tombait',
#  'voulait',
#  'affecter',
#  'gaîne',
#  'emporta',
#  'emporta',
#  'emporta',
#  'emporta',
#  'nommait',
#  'voyageait',
#  'venu',
#  'devait',
#  'comptait',
#  'savait',
#  'fait',
#  'recherchée',
#  'tenait',
#  'pris',
#  'tira',
#  'prenait',
#  'trouvait',
#  'trouvait',
#  'verrez',
#  'trouvait',
#  'supposait',
#  'aperçut',
#  'répondit',
#  'engagea',
#  'le',
#  'dit',
#  'devinerait',
#  'pouvais',
#  'n’',
#  'n’',
#  'tenu',
#  'coucherai',
#  'ravis',
#  'jette',
#  'écrivais',
#  'pleurerais',
#  'saignerais',
#  'souffrirais',
#  'souffre',
#  'vois',
#  'a',
#  'venu',
#  'te',
#  'regarde',
#  'aimait',
#  'maudira',
#  'tient',
#  'voudrais',
#  'reviens',
#  'te',
#  'demande',
#  'pourrait',
#  'mourrait',
#  'demanderais',
#  'n’',
#  'voulu',
#  'tâche',
#  'te',
#  'n’',
#  'n’',
#  'déjà.–',
#  'causez',
#  'dit',
#  'vais',
#  'fit',
#  'vit',
#  'voilà',
#  'aviez',
#  'appelleriez',
#  'mangerait',
#  'dit',
#  'regarda',
#  'dit',
#  'aide',
#  'dit',
#  'rêve',
#  'venu',
#  'sais',
#  'voyait',
#  'voulez',
#  'répondit',
#  'répondit',
#  'semblable',
#  'avait',
#  'garantis',
#  'n’',
#  'fait',
#  'tendit',
#  'montrait',
#  'bordé',
#  'tenta',
#  'dit',
#  'dit',
#  'sucrait',
#  'devait',
#  'dit',
#  'suivit',
#  'examinait',
#  'dit',
#  'trouverai',
#  'répondit',
#  'répondit',
#  'resta',
#  'emprunté',
#  'dit',
#  'écoutait',
#  'ruiné',
#  'sauva',
#  'dit',
#  'n’',
#  'n’',
#  'n’',
#  'décampera',
#  'révolutionne',
#  'pris',
#  'laisse',
#  'retourna',
#  'pensant',
#  'veux',
#  'sais',
#  'dois',
#  'n’',
#  'ferai',
#  'tournant',
#  'envoie',
#  'envoie',
#  'dédaigné',
#  'dormait',
#  'rêvait',
#  'sympathiquement',
#  'ouvrit',
#  'cru',
#  'ouvrit',
#  'dit',
#  'vit',
#  'vit',
#  'connaissait',
#  'admira',
#  'moquait',
#  'entra',
#  'n’',
#  'sais',
#  'dire',
#  'pressé',
#  'décampa',
#  'taisait',
#  'avait',
#  'dit',
#  'vint',
#  'pouvait',
#  'regarda',
#  'devriez',
#  'regarda',
#  'enveloppait',
#  'voulait',
#  'voulait',
#  'laisser',
#  'nommait',
#  'écria',
#  'fit',
#  'répéta',
#  'aime',
#  'aime',
#  'aime',
#  'a',
#  'vendu',
#  'dit',
#  'a',
#  'souffrira',
#  'reprit',
#  'dois',
#  'pourrais',
#  'dit',
#  'payerais',
#  'saisit',
#  'veux',
#  'veux',
#  'veux',
#  'partirai',
#  'viendrai',
#  'voulait',
#  'point',
#  'commencé',
#  'dit',
#  'revenait',
#  'lia',
#  'devait',
#  'reparaissait',
#  'laissée',
#  'résolut',
#  'revit',
#  'respira',
#  'pouvait',
#  'pouvait',
#  'trouva',
#  'commandé',
#  'montrait',
#  'reçut',
#  'reconnut',
#  'saurais',
#  'n’',
#  'nommerai',
#  'arrive',
#  'est',
#  'dit',
#  'dois',
#  'vais',
#  'eut',
#  'devint',
#  'administra',
#  'remplaça',
#  'passait',
#  'ordinairement',
#  'aimait',
#  'mettait',
#  'donné',
#  'tirait',
#  'manquait',
#  'croyait',
#  'dit',
#  'dit',
#  'vais',
#  'savez',
#  'prit',
#  'alla',
#  'raccommodait',
#  'levèrent',
#  'quittait',
#  'revint',
#  'dit',
#  'dit',
#  'écrasait',
#  'présenta',
#  'dit',
#  'suivit',
#  'regardait',
#  'n’',
#  'pouvez',
#  'entrée',
#  'appelé',
#  'n’',
#  'ouvrit',
#  'respirer',
#  'regarda',
#  'répondit',
#  'dressa',
#  'serrée',
#  'tricota',
#  'tourna',
#  'veut',
#  'm’',
#  'dit',
#  'avez',
#  'pris',
#  'dit',
#  'gèle',
#  'arrivée',
#  'pense',
#  'voulez',
#  'gagnait',
#  'apuré',
#  'allait',
#  'souffre',
#  'sortirai',
#  'voulez',
#  'porté',
#  'décampe',
#  'donné',
#  'point',
#  'apportait',
#  'passait',
#  'regrette',
#  'asseyait',
#  'agissait',
#  'écoutait',
#  'répondait',
#  'disait',
#  'ferai',
#  'dois',
#  'réclame',
#  'sais',
#  'ferez',
#  'dû',
#  'savez',
#  'allez',
#  'n’',
#  'seriez',
#  'mourait',
#  'devriez',
#  'commun',
#  'pouvez',
#  'demanderez',
#  'appelez',
#  'chantez',
#  'commençait',
#  'tiré',
#  'apprêtait',
#  'dois',
#  'évanouit',
#  'étonnées.–',
#  'n’',
#  'avons',
#  'manifestait',
#  'réservait',
#  'nommée',
#  'appartenait',
#  'n’',
#  'passait',
#  'faisait',
#  'faisait',
#  'allait',
#  'levait',
#  'obéissait',
#  'reçut',
#  'pouvait',
#  'laissé',
#  'faisait',
#  'riait',
#  'jetait',
#  'passerait',
#  'lavé',
#  'quittait',
#  'venait',
#  'pouvait',
#  'devait',
#  'alluma',
#  'alla',
#  'dit',
#  'rafistole',
#  'riait',
#  'dit',
#  'achètera',
#  'connaissait',
#  'va',
#  'va',
#  'alla',
#  'ronflait',
#  'dit',
#  'vais',
#  'trayait',
#  'dit',
#  'partit',
#  'peux',
#  'vu',
#  'dit',
#  'donna',
#  'crois',
#  'descendit',
#  'prit',
#  'demandés',
#  'donnés',
#  'apprendrai',
#  'quitté',
#  'regardait',
#  'vinrent',
#  'vint',
#  'dit',
#  'mis',
#  'pris',
#  'n’',
#  'commencé',
#  'savons',
#  'allé',
#  'verrouilla',
#  'encaissait',
#  'attendait',
#  'cria',
#  'n’',
#  'appelait',
#  'vint',
#  'dois',
#  'dit',
#  'm’',
#  'faisait',
#  'imprimait',
#  'lâché',
#  'voulut',
#  'voudrais',
#  'compris',
#  'pouvait',
#  'disait',
#  'mourrai',
#  'vois',
#  'grosse',
#  'portera',
#  'mangerai',
#  'faisait',
#  'apportait',
#  'possédant',
#  'aurez',
#  'dit',
#  'savez',
#  'tira',
#  'tenait',
#  'a',
#  'a',
#  'voulez',
#  'ferez',
#  'restiez',
#  'voulu',
#  'sauverez',
#  'regarde.–',
#  'plaît',
#  'sauverez',
#  'pourrez',
#  'voudrez',
#  'mettrez',
#  'vais',
#  'vais',
#  'rencontre',
#  'devez',
#  'tira',
#  'aviez',
#  'aurez',
#  'n’',
#  'va',
#  'réuni',
#  'possède',
#  'pouvaient',
#  'voulais',
#  'reviendrai',
#  'partit',
#  'courait',
#  'sais',
#  'causé',
#  'crois',
#  'verrai',
#  'dit',
#  'voulez',
#  'trouvait',
#  'répondait',
#  'changea',
#  'n’',
#  'tient',
#  'avez',
#  'narguez',
#  'crois',
#  'entendez',
#  'regarda',
#  'amoindrirez',
#  'sauverez',
#  'causera',
#  'sert',
#  'donnez',
#  'verrez',
#  'prenez',
#  'voulez',
#  'pardonne',
#  'pardonne',
#  'aurez',
#  'rendu',
#  'tuerez',
#  'peut',
#  'déclaré',
#  'entendez',
#  'savez',
#  'vais',
#  'bégayait',
#  'avait',
#  'noyait',
#  'sais',
#  'veux',
#  'puis',
#  ...]

# %%
# Sauvegarder un JSON
with open('data.json', 'w', encoding='utf-8') as f:
    json.dump(data, f)

# %% [markdown]
# ### PDF
#
# Lecture et analyse des fichiers PDF peuvent être réalisées avec l'objet PdfReader de la bibliothèque [PyPDF](https://pypdf2.readthedocs.io/en/3.0.0/index.html), comme illustré par les lignes de code suivantes :

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import PyPDF2 as PDF

# %%
## Changer le chemin ! 
file_path = '/home/crazyjeannot/Documents/cours/2024/Python4DH/data/pdf/sarrasine_english.pdf'
pdf = PDF.PdfReader(file_path)

# %%
pdf

# %%
n_pages = len(pdf.pages)
print(f'PDF has {n_pages} pages.')
# Out:
# PDF has 47 pages.

# %%
pdf.pages[15]
# Out:
# {'/Type': '/Page',
#  '/Contents': {'/Filter': '/FlateDecode'},
#  '/MediaBox': [0, 0, 612, 792],
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 47,
#   '/Kids': [IndirectObject(153, 1, 139791860096624),
#    IndirectObject(2, 0, 139791860096624),
#    IndirectObject(8, 0, 139791860096624),
#    IndirectObject(10, 0, 139791860096624),
#    IndirectObject(14, 0, 139791860096624),
#    IndirectObject(17, 0, 139791860096624),
#    IndirectObject(21, 0, 139791860096624),
#    IndirectObject(23, 0, 139791860096624),
#    IndirectObject(25, 0, 139791860096624),
#    IndirectObject(27, 0, 139791860096624),
#    IndirectObject(29, 0, 139791860096624),
#    IndirectObject(31, 0, 139791860096624),
#    IndirectObject(33, 0, 139791860096624),
#    IndirectObject(35, 0, 139791860096624),
#    IndirectObject(37, 0, 139791860096624),
#    IndirectObject(39, 0, 139791860096624),
#    IndirectObject(41, 0, 139791860096624),
#    IndirectObject(43, 0, 139791860096624),
#    IndirectObject(45, 0, 139791860096624),
#    IndirectObject(47, 0, 139791860096624),
#    IndirectObject(49, 0, 139791860096624),
#    IndirectObject(51, 0, 139791860096624),
#    IndirectObject(53, 0, 139791860096624),
#    IndirectObject(55, 0, 139791860096624),
#    IndirectObject(57, 0, 139791860096624),
#    IndirectObject(59, 0, 139791860096624),
#    IndirectObject(61, 0, 139791860096624),
#    IndirectObject(63, 0, 139791860096624),
#    IndirectObject(65, 0, 139791860096624),
#    IndirectObject(67, 0, 139791860096624),
#    IndirectObject(69, 0, 139791860096624),
#    IndirectObject(114, 0, 139791860096624),
#    IndirectObject(115, 0, 139791860096624),
#    IndirectObject(116, 0, 139791860096624),
#    IndirectObject(117, 0, 139791860096624),
#    IndirectObject(118, 0, 139791860096624),
#    IndirectObject(119, 0, 139791860096624),
#    IndirectObject(120, 0, 139791860096624),
#    IndirectObject(121, 0, 139791860096624),
#    IndirectObject(122, 0, 139791860096624),
#    IndirectObject(123, 0, 139791860096624),
#    IndirectObject(124, 0, 139791860096624),
#    IndirectObject(125, 0, 139791860096624),
#    IndirectObject(126, 0, 139791860096624),
#    IndirectObject(127, 0, 139791860096624),
#    IndirectObject(128, 0, 139791860096624),
#    IndirectObject(129, 0, 139791860096624)]},
#  '/Resources': {'/ExtGState': {'/G3': {'/BM': '/Normal', '/ca': 1}},
#   '/Font': {'/F15': {'/Type': '/Font',
#     '/BaseFont': '/CAAAAA+TimesNewRomanPS-ItalicMT',
#     '/DescendantFonts': [IndirectObject(103, 0, 139791860096624)],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {'/Filter': '/FlateDecode'}},
#    '/F5': {'/Type': '/Font',
#     '/BaseFont': '/BAAAAA+TimesNewRomanPSMT',
#     '/DescendantFonts': [IndirectObject(99, 0, 139791860096624)],
#     '/Encoding': '/Identity-H',
#     '/Subtype': '/Type0',
#     '/ToUnicode': {'/Filter': '/FlateDecode'}}},
#   '/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI']},
#  '/StructParents': 14}

# %%
page = pdf.pages[15]

# %%
content = page.extract_text()
print(content)
# Out:
# I hesitated.
# “I insist upon knowing,” she added earnestly .
# “I believe,” I said, “that this Adonis  represents a—a relative of Madame
# de Lanty .”
# I had the chagrin of seeing that she was lost in contemplatio n of that
# figure. She sat down in silence, and I seated myself beside her and took her
# hand without her noticing it. Forgotten for a portrait! At that moment we
# heard in the silence a woman’ s footstep and the faint rustling of a dress. We
# saw the youthfu l Marianina enter the boudoir , even more resplendent by
# reason of her grace and her fresh costume; she was walking slowly and
# leading with motherly care, with a daughter ’s solicitude, the spectre in
# human attire, who had driven us from the music-room; as she led him, she
# watched with some anxiety the slow movement of his feeble feet. They
# walked painfully across the boudoir to a door hidden in the hangings.
# Marianina knocked softly . Instantly a tall, thin man, a sort of familiar spirit,
# appeared as if by magic. Before entrusting the old man to this mysterious
# guardian, the lovely child, with deep veneration, kissed the ambulatory
# corpse, and her chaste caress was not without a touch of that graceful
# playfulness, the secret of which only a few privileged women possess.
# “Addio, addio! ” she said, with the sweetest inflection of her young voice.
# She added to the last syllable a wonderfully executed trill, in a very low
# tone, as if to depict the overflowing affection of her heart by a poetic
# expression. The old man, sudde nly arrested by some memory , remained on
# the threshold of that secret retreat. In the profound silence we heard the sigh
# that came forth form his breast;  he removed the most beautiful of the rings
# with which his skeleton fingers  were laden, and placed it in Marianina’ s
# bosom. The young madcap laughed, plucked out the ring, slipped it on one
# of her fingers over her glove, and ran hastily back toward the salon, where
# the orchestra were, at that moment, beginning the prelude of a contra-dance.
# She spied us.
# “Ah! were you here?” she said, blushing.
# After a searchin g glance at us as if to question us, she ran away to her
# partner with the careless petulance of her years.
# “What does this mean?” queried my young partner . “Is he her husband? I
# believe I am dreaming. Where am I?”

# %% [markdown]
# l'analyse des données à partir de fichiers PDF est loin d'être parfaite, en particulier l'extraction des sauts de ligne qui peut être particulièrement difficile
